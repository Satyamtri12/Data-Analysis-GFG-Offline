# %%
pip install qrcode
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting qrcode
#   Downloading qrcode-8.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: colorama in c:\users\satyam tripathi\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from qrcode) (0.4.6)
# Downloading qrcode-8.2-py3-none-any.whl (45 kB)
# Installing collected packages: qrcode
# Successfully installed qrcode-8.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import qrcode as qr

# %%
img = qr.make("https://github.com/Satyamtri12")
img.save("wscube_github.png")

# %%
import qrcode

# %%
pip install PIL
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement PIL (from versions: none)
# ERROR: No matching distribution found for PIL

# %%
import PIL

# %%
from PIL import Image

# %%
qr = qrcode.QRCode(version=1, 
                   error_correction=qrcode.constants.ERROR_CORRECT_H,
                   box_size=10, border=4,)
qr.add_data("https://github.com/Satyamtri12")
qr.make(fit=True)
img=qr.make_image(fill_color="red",back_color="white")
img.save("wscube_github.png")
