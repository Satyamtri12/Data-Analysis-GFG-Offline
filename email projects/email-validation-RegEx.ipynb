# %%
# a-z wscube@gmail.com
# 0-9
# . _ time 1
# @ time 1
# . 2, 3
import re

# %%
email_condition = "^[a-z]+[\._]?[a-z 0-9]+[@]\w+[.]\w{2,3}$"
user_email = input("Enter your Email: ")

if re.search(email_condition, user_email):
    print("Right Email")
else:
    print("Wrong Email")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\satyam tripathi\AppData\Local\Temp\ipykernel_16120\219278532.py:1: SyntaxWarning: invalid escape sequence '\.'
#   email_condition = "^[a-z]+[\._]?[a-z 0-9]+[@]\w+[.]\w{2,3}$"
# Right Email
